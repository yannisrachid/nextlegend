# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [
  {'team': 'Ajax', 'country': 'Netherlands', 'indicator_score': 87.0,
   'avg_age_team': 24.6, 'avg_age_cb': 22.0,
   'recent_exits': 'de Ligt (19) → Juventus; Lisandro Martínez (24) → Man United',
   'recent_cb_exits': 2},

  {'team': 'RB Leipzig', 'country': 'Germany', 'indicator_score': 78.7,
   'avg_age_team': 24.6, 'avg_age_cb': 24.0,
   'recent_exits': 'Konaté (22) → Liverpool 2021; Gvardiol (21) → Man City 2023',
   'recent_cb_exits': 2},

  {'team': 'Benfica', 'country': 'Portugal', 'indicator_score': 61.9,
   'avg_age_team': 24.2, 'avg_age_cb': 22.5,
   'recent_exits': 'Rúben Dias (23) → Man City 2020; António Silva (courtisé)',
   'recent_cb_exits': 1},

  {'team': 'AS Monaco', 'country': 'France', 'indicator_score': 61.1,
   'avg_age_team': 24.5, 'avg_age_cb': 25.5,
   'recent_exits': 'Badiashile (21) & Disasi (25) → Chelsea 2023',
   'recent_cb_exits': 2},

  {'team': 'Lille', 'country': 'France', 'indicator_score': 60.7,
   'avg_age_team': 24.5, 'avg_age_cb': 23.0,
   'recent_exits': 'Leny Yoro (18) → Real Madrid 2024',
   'recent_cb_exits': 1},

  {'team': 'AZ Alkmaar', 'country': 'Netherlands', 'indicator_score': 58.7,
   'avg_age_team': 24.0, 'avg_age_cb': 24.0,
   'recent_exits': 'Beukema (25) → Bologna 2023',
   'recent_cb_exits': 1},

  {'team': 'Anderlecht', 'country': 'Belgium', 'indicator_score': 55.0,
   'avg_age_team': 23.5, 'avg_age_cb': 25.0,
   'recent_exits': 'Zeno Debast (20) → Sporting 2024',
   'recent_cb_exits': 1},

  {'team': 'Bologna', 'country': 'Italy', 'indicator_score': 52.1,
   'avg_age_team': 24.5, 'avg_age_cb': 24.5,
   'recent_exits': 'Calafiori (22) → Arsenal 2024',
   'recent_cb_exits': 1},

  {'team': 'Borussia Dortmund', 'country': 'Germany', 'indicator_score': 50.0,
   'avg_age_team': 26.0, 'avg_age_cb': 27.5,
   'recent_exits': 'Hummels (hist.), Zagadou → VfB',
   'recent_cb_exits': 1},

  {'team': 'Feyenoord', 'country': 'Netherlands', 'indicator_score': 50.0,
   'avg_age_team': 24.9, 'avg_age_cb': 25.0,
   'recent_exits': 'Geertruida (23, RB/CB) → PSG 2024',
   'recent_cb_exits': 1},

  {'team': 'Genk', 'country': 'Belgium', 'indicator_score': 50.0,
   'avg_age_team': 24.5, 'avg_age_cb': 25.0,
   'recent_exits': 'Koulibaly (23) → Napoli 2014 (hist.)',
   'recent_cb_exits': 1},

  {'team': 'Lyon', 'country': 'France', 'indicator_score': 49.2,
   'avg_age_team': 25.5, 'avg_age_cb': 24.0,
   'recent_exits': 'Castello Lukeba (20) → RB Leipzig 2023',
   'recent_cb_exits': 1},

  {'team': 'FC Porto', 'country': 'Portugal', 'indicator_score': 45.0,
   'avg_age_team': 25.0, 'avg_age_cb': 25.5,
   'recent_exits': 'Éder Militão (21) → Real 2019',
   'recent_cb_exits': 1},

  {'team': 'Real Sociedad', 'country': 'Spain', 'indicator_score': 42.9,
   'avg_age_team': 25.9, 'avg_age_cb': 26.0,
   'recent_exits': 'Le Normand (27) → Atlético 2024',
   'recent_cb_exits': 1},

  {'team': 'Atalanta', 'country': 'Italy', 'indicator_score': 40.8,
   'avg_age_team': 25.5, 'avg_age_cb': 26.0,
   'recent_exits': 'Romero (23) → Tottenham 2021',
   'recent_cb_exits': 1},

  {'team': 'FC Barcelona', 'country': 'Spain', 'indicator_score': 35.0,
   'avg_age_team': 25.5, 'avg_age_cb': 22.0,
   'recent_exits': 'Cubarsí (U18) promu',
   'recent_cb_exits': 0},

  {'team': 'Sporting CP', 'country': 'Portugal', 'indicator_score': 30.8,
   'avg_age_team': 25.3, 'avg_age_cb': 22.0,
   'recent_exits': 'Inácio/Diomande très suivis',
   'recent_cb_exits': 0},

  {'team': 'Bayer Leverkusen', 'country': 'Germany', 'indicator_score': 25.0,
   'avg_age_team': 25.8, 'avg_age_cb': 26.5,
   'recent_exits': '— (pipeline constant)',
   'recent_cb_exits': 0},

  {'team': 'PSV', 'country': 'Netherlands', 'indicator_score': 22.9,
   'avg_age_team': 25.0, 'avg_age_cb': 25.5,
   'recent_exits': '—',
   'recent_cb_exits': 0},

  {'team': 'RB Salzburg', 'country': 'Austria', 'indicator_score': 60.4,
   'avg_age_team': 22.7, 'avg_age_cb': 24.5,
   'recent_exits': 'Pavlović / Solet valorisés; nombreuses ventes RB',
   'recent_cb_exits': 1}
]

# %%
len(data)
# Out:
# 20
